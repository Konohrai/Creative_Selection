# %%
# Import libraries
import numpy as np
import pandas as pd
import datetime as dt
import os
import pickle
import json

# SetUp the path
path = os.chdir('/Users/mac/Documents/Voodoo/ADN-DS')

# Load_data
df_all = pd.read_csv('modeling_ipm_data_v2.csv', index_col = False)
    

# Get last 7 days from dataset (embedding includet into last date)
df_all = df_all[pd.to_datetime(df_all['date']) == pd.to_datetime(df_all.date.max())]

# Group data and calculate 'total_impressions' and 'total_install'
def Total_Data_IPM(df, features, group_by_feature, sort_features):    

        # Create dataset for AD Selection task
        df = df[features]

        df_grouped = df.groupby(group_by_feature)['window_impressions', 'window_installs'].sum()

        df_grouped.rename(columns = {'window_impressions':'total_impressions', 'window_installs':'total_install'}, inplace = True)

        df = df_grouped.reset_index()

        # Sort values
        df.sort_values(sort_features)

        return df
    
def ad_weights(df_all):
   
    # Grouping data for model
    df_group = Total_Data_IPM(df_all, 
                             ['promoted_app', 'ad_id', 'window_impressions','window_installs'], 
                             ['promoted_app', "ad_id"],
                              'promoted_app')
    
    # Load model
    with open('Model/ad_selection_model.pkl', 'rb') as buff:
        data = pickle.load(buff)  

    model, trace = data['model'], data['trace']
    
    # Create weights
    weights = {}
    for bundle_id, sub_df in df_group.groupby('promoted_app'):
        # Choose sampling data for each creative_id    
        data = trace.posterior.p.data[:, :, sub_df.index.values]
        # Reshape
        data = np.concatenate(data, axis=0)
        # Find creative_id with max values in each sampling columns
        argmax = data.argmax(axis=1)
        # Building pair: Probability Mass Function <-> creative_id
        pmf, _ = np.histogram(argmax, bins=np.arange(data.shape[1] + 1), density = True)
        # Fill the dict {target_bundle_id: ['creative_id' : pmf]}
        weights[bundle_id] = {creative: weight for creative, weight in zip(sub_df['ad_id'], pmf)}
    
    with open('Weights/weights.json', 'w') as fp:
        json.dump(weights, fp)
    
    return weights

# %%
ad_weights(df_all)
# Out:
# /var/folders/57/nx0ld9vx17l0yw9shbwxhk440000gn/T/ipykernel_1662/3907572153.py:25: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_grouped = df.groupby(group_by_feature)['window_impressions', 'window_installs'].sum()
# {'io.voodoo.game_0': {'ad:promoted-app=0-0': 1.0},
#  'io.voodoo.game_1': {'ad:promoted-app=1-0': 1.0},
#  'io.voodoo.game_101': {'ad:promoted-app=101-0': 1.0},
#  'io.voodoo.game_102': {'ad:promoted-app=102-0': 0.5,
#   'ad:promoted-app=102-1': 0.1485,
#   'ad:promoted-app=102-2': 0.21575,
#   'ad:promoted-app=102-3': 0.13575},
#  'io.voodoo.game_103': {'ad:promoted-app=103-0': 1.0},
#  'io.voodoo.game_104': {'ad:promoted-app=104-0': 1.0},
#  'io.voodoo.game_105': {'ad:promoted-app=105-0': 1.0},
#  'io.voodoo.game_106': {'ad:promoted-app=106-0': 1.0},
#  'io.voodoo.game_107': {'ad:promoted-app=107-0': 1.0},
#  'io.voodoo.game_108': {'ad:promoted-app=108-0': 0.0,
#   'ad:promoted-app=108-1': 0.0,
#   'ad:promoted-app=108-2': 0.0,
#   'ad:promoted-app=108-3': 0.25,
#   'ad:promoted-app=108-4': 0.0045,
#   'ad:promoted-app=108-5': 0.2455,
#   'ad:promoted-app=108-6': 0.0,
#   'ad:promoted-app=108-7': 0.0,
#   'ad:promoted-app=108-8': 0.5},
#  'io.voodoo.game_11': {'ad:promoted-app=212-0': 1.0},
#  'io.voodoo.game_110': {'ad:promoted-app=110-0': 1.0,
#   'ad:promoted-app=110-1': 0.0,
#   'ad:promoted-app=110-2': 0.0,
#   'ad:promoted-app=110-3': 0.0},
#  'io.voodoo.game_111': {'ad:promoted-app=111-0': 1.0},
#  'io.voodoo.game_112': {'ad:promoted-app=112-0': 0.64825,
#   'ad:promoted-app=112-1': 0.30825,
#   'ad:promoted-app=112-2': 0.0435},
#  'io.voodoo.game_113': {'ad:promoted-app=113-0': 1.0},
#  'io.voodoo.game_115': {'ad:promoted-app=115-0': 0.4165,
#   'ad:promoted-app=115-1': 0.5835},
#  'io.voodoo.game_116': {'ad:promoted-app=116-0': 0.0,
#   'ad:promoted-app=116-1': 0.0,
#   'ad:promoted-app=116-10': 0.0,
#   'ad:promoted-app=116-11': 0.0,
#   'ad:promoted-app=116-2': 0.0,
#   'ad:promoted-app=116-3': 0.0,
#   'ad:promoted-app=116-4': 0.0,
#   'ad:promoted-app=116-5': 0.0,
#   'ad:promoted-app=116-6': 0.0,
#   'ad:promoted-app=116-7': 0.0,
#   'ad:promoted-app=116-8': 1.0,
#   'ad:promoted-app=116-9': 0.0},
#  'io.voodoo.game_117': {'ad:promoted-app=117-0': 1.0},
#  'io.voodoo.game_118': {'ad:promoted-app=118-0': 1.0},
#  'io.voodoo.game_119': {'ad:promoted-app=119-0': 1.0},
#  'io.voodoo.game_12': {'ad:promoted-app=12-0': 0.02975,
#   'ad:promoted-app=12-1': 0.97025},
#  'io.voodoo.game_120': {'ad:promoted-app=120-0': 1.0},
#  'io.voodoo.game_121': {'ad:promoted-app=121-0': 1.0},
#  'io.voodoo.game_122': {'ad:promoted-app=122-0': 1.0},
#  'io.voodoo.game_123': {'ad:promoted-app=123-0': 1.0},
#  'io.voodoo.game_124': {'ad:promoted-app=124-0': 1.0},
#  'io.voodoo.game_125': {'ad:promoted-app=125-0': 0.0,
#   'ad:promoted-app=125-1': 0.0,
#   'ad:promoted-app=125-10': 0.0095,
#   'ad:promoted-app=125-11': 0.0,
#   'ad:promoted-app=125-12': 0.0,
#   'ad:promoted-app=125-13': 0.0,
#   'ad:promoted-app=125-14': 0.0,
#   'ad:promoted-app=125-15': 0.25,
#   'ad:promoted-app=125-16': 0.0,
#   'ad:promoted-app=125-17': 0.0,
#   'ad:promoted-app=125-18': 0.0,
#   'ad:promoted-app=125-19': 0.0,
#   'ad:promoted-app=125-2': 0.0,
#   'ad:promoted-app=125-20': 0.0,
#   'ad:promoted-app=125-21': 0.0,
#   'ad:promoted-app=125-22': 0.0,
#   'ad:promoted-app=125-23': 0.0,
#   'ad:promoted-app=125-24': 0.25,
#   'ad:promoted-app=125-25': 0.0,
#   'ad:promoted-app=125-26': 0.0,
#   'ad:promoted-app=125-27': 0.4905,
#   'ad:promoted-app=125-3': 0.0,
#   'ad:promoted-app=125-4': 0.0,
#   'ad:promoted-app=125-5': 0.0,
#   'ad:promoted-app=125-6': 0.0,
#   'ad:promoted-app=125-7': 0.0,
#   'ad:promoted-app=125-8': 0.0,
#   'ad:promoted-app=125-9': 0.0},
#  'io.voodoo.game_126': {'ad:promoted-app=126-0': 1.0},
#  'io.voodoo.game_127': {'ad:promoted-app=127-0': 0.0,
#   'ad:promoted-app=127-1': 0.0,
#   'ad:promoted-app=127-2': 0.0,
#   'ad:promoted-app=127-3': 0.25,
#   'ad:promoted-app=127-4': 0.25,
#   'ad:promoted-app=127-5': 0.0,
#   'ad:promoted-app=127-6': 0.0,
#   'ad:promoted-app=127-7': 0.5},
#  'io.voodoo.game_128': {'ad:promoted-app=128-0': 1.0},
#  'io.voodoo.game_129': {'ad:promoted-app=129-0': 1.0},
#  'io.voodoo.game_13': {'ad:promoted-app=13-0': 0.0105,
#   'ad:promoted-app=13-1': 0.25475,
#   'ad:promoted-app=13-2': 0.009,
#   'ad:promoted-app=13-3': 0.5195,
#   'ad:promoted-app=13-4': 0.0005,
#   'ad:promoted-app=13-5': 0.20575},
#  'io.voodoo.game_130': {'ad:promoted-app=130-0': 1.0},
#  'io.voodoo.game_131': {'ad:promoted-app=131-0': 0.0,
#   'ad:promoted-app=131-1': 0.0,
#   'ad:promoted-app=131-2': 0.0,
#   'ad:promoted-app=131-3': 0.0,
#   'ad:promoted-app=131-4': 0.0,
#   'ad:promoted-app=131-5': 0.0,
#   'ad:promoted-app=131-6': 0.0,
#   'ad:promoted-app=131-7': 0.0,
#   'ad:promoted-app=131-8': 1.0},
#  'io.voodoo.game_132': {'ad:promoted-app=132-0': 1.0},
#  'io.voodoo.game_133': {'ad:promoted-app=133-0': 0.7005,
#   'ad:promoted-app=133-1': 0.2995},
#  'io.voodoo.game_134': {'ad:promoted-app=134-0': 1.0},
#  'io.voodoo.game_135': {'ad:promoted-app=135-0': 0.0,
#   'ad:promoted-app=135-1': 0.0,
#   'ad:promoted-app=135-2': 0.0,
#   'ad:promoted-app=135-3': 0.0,
#   'ad:promoted-app=135-4': 0.0,
#   'ad:promoted-app=135-5': 0.0,
#   'ad:promoted-app=135-6': 0.0,
#   'ad:promoted-app=135-7': 0.0,
#   'ad:promoted-app=135-8': 1.0},
#  'io.voodoo.game_136': {'ad:promoted-app=136-0': 0.0,
#   'ad:promoted-app=136-1': 0.25,
#   'ad:promoted-app=136-10': 0.0,
#   'ad:promoted-app=136-2': 0.0,
#   'ad:promoted-app=136-3': 0.0,
#   'ad:promoted-app=136-4': 0.0,
#   'ad:promoted-app=136-5': 0.2855,
#   'ad:promoted-app=136-7': 0.0,
#   'ad:promoted-app=136-8': 0.06625,
#   'ad:promoted-app=136-9': 0.39825},
#  'io.voodoo.game_138': {'ad:promoted-app=138-0': 1.0},
#  'io.voodoo.game_139': {'ad:promoted-app=139-0': 1.0},
#  'io.voodoo.game_14': {'ad:promoted-app=14-0': 0.00325,
#   'ad:promoted-app=14-1': 0.00025,
#   'ad:promoted-app=14-2': 0.67675,
#   'ad:promoted-app=14-3': 0.31925,
#   'ad:promoted-app=14-4': 0.0,
#   'ad:promoted-app=14-5': 0.00025,
#   'ad:promoted-app=14-6': 0.00025,
#   'ad:promoted-app=14-7': 0.0},
#  'io.voodoo.game_140': {'ad:promoted-app=140-0': 0.11325,
#   'ad:promoted-app=140-1': 0.0285,
#   'ad:promoted-app=140-2': 0.02275,
#   'ad:promoted-app=140-3': 0.8355},
#  'io.voodoo.game_141': {'ad:promoted-app=141-0': 1.0},
#  'io.voodoo.game_142': {'ad:promoted-app=142-0': 1.0},
#  'io.voodoo.game_143': {'ad:promoted-app=143-0': 0.008,
#   'ad:promoted-app=143-1': 0.17025,
#   'ad:promoted-app=143-2': 0.053,
#   'ad:promoted-app=143-3': 0.76875},
#  'io.voodoo.game_144': {'ad:promoted-app=144-0': 0.363,
#   'ad:promoted-app=144-1': 0.00025,
#   'ad:promoted-app=144-2': 0.0,
#   'ad:promoted-app=144-3': 0.38675,
#   'ad:promoted-app=144-4': 0.0,
#   'ad:promoted-app=144-5': 0.0,
#   'ad:promoted-app=144-6': 0.25},
#  'io.voodoo.game_145': {'ad:promoted-app=145-0': 0.0,
#   'ad:promoted-app=145-1': 0.0,
#   'ad:promoted-app=145-10': 0.0,
#   'ad:promoted-app=145-11': 0.08575,
#   'ad:promoted-app=145-12': 0.16425,
#   'ad:promoted-app=145-13': 0.0,
#   'ad:promoted-app=145-14': 0.25,
#   'ad:promoted-app=145-2': 0.0,
#   'ad:promoted-app=145-3': 0.0,
#   'ad:promoted-app=145-4': 0.0,
#   'ad:promoted-app=145-5': 0.25,
#   'ad:promoted-app=145-6': 0.0,
#   'ad:promoted-app=145-7': 0.0,
#   'ad:promoted-app=145-8': 0.25,
#   'ad:promoted-app=145-9': 0.0},
#  'io.voodoo.game_146': {'ad:promoted-app=146-0': 0.1045,
#   'ad:promoted-app=146-1': 0.0465,
#   'ad:promoted-app=146-2': 0.118,
#   'ad:promoted-app=146-3': 0.00825,
#   'ad:promoted-app=146-4': 0.68,
#   'ad:promoted-app=146-5': 0.0085,
#   'ad:promoted-app=146-6': 0.03125,
#   'ad:promoted-app=146-7': 0.003},
#  'io.voodoo.game_147': {'ad:promoted-app=147-0': 0.26775,
#   'ad:promoted-app=147-1': 0.0,
#   'ad:promoted-app=147-2': 0.0,
#   'ad:promoted-app=147-3': 0.73225},
#  'io.voodoo.game_149': {'ad:promoted-app=149-0': 0.28775,
#   'ad:promoted-app=149-1': 0.0,
#   'ad:promoted-app=149-10': 0.25,
#   'ad:promoted-app=149-11': 0.0,
#   'ad:promoted-app=149-12': 0.21225,
#   'ad:promoted-app=149-13': 0.0,
#   'ad:promoted-app=149-14': 0.0,
#   'ad:promoted-app=149-2': 0.0,
#   'ad:promoted-app=149-3': 0.0,
#   'ad:promoted-app=149-4': 0.0,
#   'ad:promoted-app=149-5': 0.25,
#   'ad:promoted-app=149-6': 0.0,
#   'ad:promoted-app=149-7': 0.0,
#   'ad:promoted-app=149-8': 0.0,
#   'ad:promoted-app=149-9': 0.0},
#  'io.voodoo.game_15': {'ad:promoted-app=15-0': 1.0},
#  'io.voodoo.game_150': {'ad:promoted-app=150-0': 0.321,
#   'ad:promoted-app=150-1': 0.679},
#  'io.voodoo.game_151': {'ad:promoted-app=151-0': 1.0},
#  'io.voodoo.game_152': {'ad:promoted-app=152-0': 1.0},
#  'io.voodoo.game_153': {'ad:promoted-app=153-0': 0.243,
#   'ad:promoted-app=153-1': 0.757},
#  'io.voodoo.game_154': {'ad:promoted-app=154-0': 0.3555,
#   'ad:promoted-app=154-1': 0.6445},
#  'io.voodoo.game_156': {'ad:promoted-app=156-0': 0.14525,
#   'ad:promoted-app=156-1': 0.42275,
#   'ad:promoted-app=156-2': 0.15025,
#   'ad:promoted-app=156-3': 0.2315,
#   'ad:promoted-app=156-4': 0.05025},
#  'io.voodoo.game_157': {'ad:promoted-app=157-0': 0.999,
#   'ad:promoted-app=157-1': 0.001},
#  'io.voodoo.game_159': {'ad:promoted-app=159-0': 1.0},
#  'io.voodoo.game_16': {'ad:promoted-app=16-0': 1.0},
#  'io.voodoo.game_160': {'ad:promoted-app=160-0': 1.0},
#  'io.voodoo.game_161': {'ad:promoted-app=161-0': 0.45125,
#   'ad:promoted-app=161-1': 0.01725,
#   'ad:promoted-app=161-2': 0.43025,
#   'ad:promoted-app=161-3': 0.10125},
#  'io.voodoo.game_162': {'ad:promoted-app=162-0': 1.0},
#  'io.voodoo.game_163': {'ad:promoted-app=163-0': 0.00425,
#   'ad:promoted-app=163-1': 0.42025,
#   'ad:promoted-app=163-2': 0.35425,
#   'ad:promoted-app=163-3': 0.17775,
#   'ad:promoted-app=163-4': 0.03125,
#   'ad:promoted-app=163-5': 0.01225},
#  'io.voodoo.game_164': {'ad:promoted-app=164-0': 0.0855,
#   'ad:promoted-app=164-1': 0.0,
#   'ad:promoted-app=164-10': 0.0,
#   'ad:promoted-app=164-11': 0.0,
#   'ad:promoted-app=164-12': 0.25,
#   'ad:promoted-app=164-2': 0.0,
#   'ad:promoted-app=164-3': 0.0,
#   'ad:promoted-app=164-4': 0.0,
#   'ad:promoted-app=164-5': 0.25,
#   'ad:promoted-app=164-6': 0.25,
#   'ad:promoted-app=164-7': 0.0,
#   'ad:promoted-app=164-8': 0.0,
#   'ad:promoted-app=164-9': 0.1645},
#  'io.voodoo.game_165': {'ad:promoted-app=165-0': 0.0,
#   'ad:promoted-app=165-1': 0.00125,
#   'ad:promoted-app=165-2': 0.9635,
#   'ad:promoted-app=165-3': 0.03425,
#   'ad:promoted-app=165-4': 0.0,
#   'ad:promoted-app=165-5': 0.00075,
#   'ad:promoted-app=165-6': 0.00025,
#   'ad:promoted-app=165-7': 0.0},
#  'io.voodoo.game_166': {'ad:promoted-app=166-0': 1.0},
#  'io.voodoo.game_167': {'ad:promoted-app=167-0': 0.0,
#   'ad:promoted-app=167-1': 0.2755,
#   'ad:promoted-app=167-2': 0.0,
#   'ad:promoted-app=167-3': 0.7245},
#  'io.voodoo.game_168': {'ad:promoted-app=168-0': 1.0},
#  'io.voodoo.game_169': {'ad:promoted-app=169-0': 0.2175,
#   'ad:promoted-app=169-1': 0.077,
#   'ad:promoted-app=169-2': 0.173,
#   'ad:promoted-app=169-3': 0.5325},
#  'io.voodoo.game_170': {'ad:promoted-app=170-0': 1.0},
#  'io.voodoo.game_171': {'ad:promoted-app=171-0': 1.0},
#  'io.voodoo.game_172': {'ad:promoted-app=172-0': 1.0},
#  'io.voodoo.game_173': {'ad:promoted-app=173-0': 0.25,
#   'ad:promoted-app=173-1': 0.0,
#   'ad:promoted-app=173-2': 0.0,
#   'ad:promoted-app=173-3': 0.0,
#   'ad:promoted-app=173-4': 0.5,
#   'ad:promoted-app=173-5': 0.15775,
#   'ad:promoted-app=173-6': 0.0,
#   'ad:promoted-app=173-7': 0.09225},
#  'io.voodoo.game_174': {'ad:promoted-app=174-0': 0.0,
#   'ad:promoted-app=174-1': 0.0,
#   'ad:promoted-app=174-10': 0.36775,
#   'ad:promoted-app=174-2': 0.0,
#   'ad:promoted-app=174-3': 0.079,
#   'ad:promoted-app=174-4': 0.0255,
#   'ad:promoted-app=174-5': 0.0,
#   'ad:promoted-app=174-6': 0.52775,
#   'ad:promoted-app=174-7': 0.0,
#   'ad:promoted-app=174-8': 0.0,
#   'ad:promoted-app=174-9': 0.0},
#  'io.voodoo.game_175': {'ad:promoted-app=175-0': 1.0},
#  'io.voodoo.game_176': {'ad:promoted-app=176-0': 0.00275,
#   'ad:promoted-app=176-1': 0.434,
#   'ad:promoted-app=176-2': 0.1745,
#   'ad:promoted-app=176-3': 0.38875},
#  'io.voodoo.game_177': {'ad:promoted-app=177-0': 1.0},
#  'io.voodoo.game_178': {'ad:promoted-app=178-0': 1.0},
#  'io.voodoo.game_18': {'ad:promoted-app=18-0': 1.0},
#  'io.voodoo.game_181': {'ad:promoted-app=181-0': 0.19475,
#   'ad:promoted-app=181-1': 0.80525},
#  'io.voodoo.game_182': {'ad:promoted-app=182-0': 0.0,
#   'ad:promoted-app=182-1': 0.0,
#   'ad:promoted-app=182-10': 0.0,
#   'ad:promoted-app=182-11': 0.14925,
#   'ad:promoted-app=182-12': 0.0,
#   'ad:promoted-app=182-13': 0.0,
#   'ad:promoted-app=182-14': 0.5,
#   'ad:promoted-app=182-2': 0.0,
#   'ad:promoted-app=182-3': 0.0,
#   'ad:promoted-app=182-4': 0.0,
#   'ad:promoted-app=182-5': 0.0,
#   'ad:promoted-app=182-6': 0.35075,
#   'ad:promoted-app=182-7': 0.0,
#   'ad:promoted-app=182-8': 0.0,
#   'ad:promoted-app=182-9': 0.0},
#  'io.voodoo.game_183': {'ad:promoted-app=183-0': 1.0},
#  'io.voodoo.game_184': {'ad:promoted-app=184-0': 1.0},
#  'io.voodoo.game_186': {'ad:promoted-app=186-0': 1.0},
#  'io.voodoo.game_187': {'ad:promoted-app=187-0': 1.0},
#  'io.voodoo.game_189': {'ad:promoted-app=189-0': 1.0},
#  'io.voodoo.game_19': {'ad:promoted-app=19-0': 0.0,
#   'ad:promoted-app=19-1': 0.0,
#   'ad:promoted-app=19-10': 0.0,
#   'ad:promoted-app=19-2': 0.0475,
#   'ad:promoted-app=19-3': 0.4345,
#   'ad:promoted-app=19-4': 0.0,
#   'ad:promoted-app=19-5': 0.0,
#   'ad:promoted-app=19-6': 0.0655,
#   'ad:promoted-app=19-7': 0.4525,
#   'ad:promoted-app=19-8': 0.0,
#   'ad:promoted-app=19-9': 0.0},
#  'io.voodoo.game_190': {'ad:promoted-app=190-0': 1.0},
#  'io.voodoo.game_192': {'ad:promoted-app=192-0': 1.0},
#  'io.voodoo.game_193': {'ad:promoted-app=193-0': 0.58275,
#   'ad:promoted-app=193-1': 0.002,
#   'ad:promoted-app=193-2': 0.41525},
#  'io.voodoo.game_194': {'ad:promoted-app=194-0': 1.0},
#  'io.voodoo.game_195': {'ad:promoted-app=195-0': 0.51925,
#   'ad:promoted-app=195-1': 0.10325,
#   'ad:promoted-app=195-2': 0.3775},
#  'io.voodoo.game_196': {'ad:promoted-app=196-0': 0.016,
#   'ad:promoted-app=196-1': 0.39,
#   'ad:promoted-app=196-2': 0.51275,
#   'ad:promoted-app=196-3': 0.0,
#   'ad:promoted-app=196-4': 0.0055,
#   'ad:promoted-app=196-5': 0.0,
#   'ad:promoted-app=196-6': 0.07575},
#  'io.voodoo.game_197': {'ad:promoted-app=197-0': 1.0},
#  'io.voodoo.game_198': {'ad:promoted-app=198-0': 1.0},
#  'io.voodoo.game_199': {'ad:promoted-app=199-0': 0.4745,
#   'ad:promoted-app=199-1': 0.5255},
#  'io.voodoo.game_2': {'ad:promoted-app=2-0': 1.0},
#  'io.voodoo.game_20': {'ad:promoted-app=20-0': 0.0,
#   'ad:promoted-app=20-1': 0.434,
#   'ad:promoted-app=20-2': 0.0,
#   'ad:promoted-app=20-3': 0.133,
#   'ad:promoted-app=20-4': 0.433},
#  'io.voodoo.game_200': {'ad:promoted-app=200-0': 0.39675,
#   'ad:promoted-app=200-1': 0.4885,
#   'ad:promoted-app=200-2': 0.11475},
#  'io.voodoo.game_201': {'ad:promoted-app=201-0': 1.0},
#  'io.voodoo.game_202': {'ad:promoted-app=202-0': 1.0},
#  'io.voodoo.game_203': {'ad:promoted-app=203-0': 0.92725,
#   'ad:promoted-app=203-1': 0.07275},
#  'io.voodoo.game_204': {'ad:promoted-app=204-0': 1.0},
#  'io.voodoo.game_205': {'ad:promoted-app=205-0': 1.0},
#  'io.voodoo.game_206': {'ad:promoted-app=206-0': 1.0},
#  'io.voodoo.game_207': {'ad:promoted-app=207-0': 0.0205,
#   'ad:promoted-app=207-1': 0.50225,
#   'ad:promoted-app=207-2': 0.47725},
#  'io.voodoo.game_208': {'ad:promoted-app=208-0': 1.0},
#  'io.voodoo.game_209': {'ad:promoted-app=209-0': 0.0,
#   'ad:promoted-app=209-1': 0.0,
#   'ad:promoted-app=209-10': 0.0,
#   'ad:promoted-app=209-11': 0.0255,
#   'ad:promoted-app=209-12': 0.0,
#   'ad:promoted-app=209-13': 0.0,
#   'ad:promoted-app=209-14': 0.0,
#   'ad:promoted-app=209-15': 0.0,
#   'ad:promoted-app=209-16': 0.009,
#   'ad:promoted-app=209-17': 0.0,
#   'ad:promoted-app=209-18': 0.0,
#   'ad:promoted-app=209-19': 0.67475,
#   'ad:promoted-app=209-2': 0.0,
#   'ad:promoted-app=209-20': 0.0,
#   'ad:promoted-app=209-21': 0.0,
#   'ad:promoted-app=209-22': 0.0,
#   'ad:promoted-app=209-23': 0.0,
#   'ad:promoted-app=209-24': 0.0,
#   'ad:promoted-app=209-25': 0.0,
#   'ad:promoted-app=209-26': 0.0,
#   'ad:promoted-app=209-27': 0.25,
#   'ad:promoted-app=209-3': 0.0,
#   'ad:promoted-app=209-4': 0.0,
#   'ad:promoted-app=209-5': 0.0,
#   'ad:promoted-app=209-6': 0.04075,
#   'ad:promoted-app=209-7': 0.0,
#   'ad:promoted-app=209-8': 0.0,
#   'ad:promoted-app=209-9': 0.0},
#  'io.voodoo.game_21': {'ad:promoted-app=21-0': 1.0},
#  'io.voodoo.game_210': {'ad:promoted-app=210-0': 0.546,
#   'ad:promoted-app=210-1': 0.0,
#   'ad:promoted-app=210-10': 0.09425,
#   'ad:promoted-app=210-11': 0.0,
#   'ad:promoted-app=210-12': 0.0,
#   'ad:promoted-app=210-13': 0.0095,
#   'ad:promoted-app=210-14': 0.204,
#   'ad:promoted-app=210-15': 0.0,
#   'ad:promoted-app=210-16': 0.0,
#   'ad:promoted-app=210-2': 0.0,
#   'ad:promoted-app=210-3': 0.01875,
#   'ad:promoted-app=210-4': 0.0,
#   'ad:promoted-app=210-5': 0.1275,
#   'ad:promoted-app=210-6': 0.0,
#   'ad:promoted-app=210-7': 0.0,
#   'ad:promoted-app=210-8': 0.0,
#   'ad:promoted-app=210-9': 0.0},
#  'io.voodoo.game_211': {'ad:promoted-app=211-0': 1.0},
#  'io.voodoo.game_212': {'ad:promoted-app=212-0': 1.0},
#  'io.voodoo.game_213': {'ad:promoted-app=213-0': 1.0},
#  'io.voodoo.game_214': {'ad:promoted-app=214-0': 1.0},
#  'io.voodoo.game_215': {'ad:promoted-app=215-0': 1.0},
#  'io.voodoo.game_218': {'ad:promoted-app=218-0': 1.0},
#  'io.voodoo.game_219': {'ad:promoted-app=219-0': 1.0},
#  'io.voodoo.game_22': {'ad:promoted-app=22-0': 0.717,
#   'ad:promoted-app=22-1': 0.00025,
#   'ad:promoted-app=22-2': 0.28275},
#  'io.voodoo.game_220': {'ad:promoted-app=220-0': 1.0},
#  'io.voodoo.game_221': {'ad:promoted-app=221-0': 0.328,
#   'ad:promoted-app=221-1': 0.672},
#  'io.voodoo.game_222': {'ad:promoted-app=222-0': 0.4075,
#   'ad:promoted-app=222-1': 0.5925},
#  'io.voodoo.game_223': {'ad:promoted-app=223-0': 1.0},
#  'io.voodoo.game_224': {'ad:promoted-app=224-0': 1.0},
#  'io.voodoo.game_225': {'ad:promoted-app=225-0': 1.0},
#  'io.voodoo.game_226': {'ad:promoted-app=226-0': 0.0795,
#   'ad:promoted-app=226-1': 0.00075,
#   'ad:promoted-app=226-2': 0.07425,
#   'ad:promoted-app=226-3': 0.049,
#   'ad:promoted-app=226-4': 0.7965},
#  'io.voodoo.game_227': {'ad:promoted-app=227-0': 0.08825,
#   'ad:promoted-app=227-1': 0.22025,
#   'ad:promoted-app=227-2': 0.27425,
#   'ad:promoted-app=227-3': 0.41725},
#  'io.voodoo.game_229': {'ad:promoted-app=229-0': 0.74725,
#   'ad:promoted-app=229-1': 0.2505,
#   'ad:promoted-app=229-2': 0.001,
#   'ad:promoted-app=229-3': 0.00125},
#  'io.voodoo.game_23': {'ad:promoted-app=23-0': 0.0,
#   'ad:promoted-app=23-1': 0.5,
#   'ad:promoted-app=23-2': 0.0,
#   'ad:promoted-app=23-3': 0.0,
#   'ad:promoted-app=23-5': 0.5,
#   'ad:promoted-app=256-5': 0.0},
#  'io.voodoo.game_231': {'ad:promoted-app=231-0': 1.0},
#  'io.voodoo.game_233': {'ad:promoted-app=233-0': 0.0,
#   'ad:promoted-app=233-1': 1.0,
#   'ad:promoted-app=233-2': 0.0,
#   'ad:promoted-app=233-3': 0.0,
#   'ad:promoted-app=233-4': 0.0},
#  'io.voodoo.game_234': {'ad:promoted-app=234-0': 1.0},
#  'io.voodoo.game_235': {'ad:promoted-app=235-0': 1.0},
#  'io.voodoo.game_236': {'ad:promoted-app=236-0': 0.0,
#   'ad:promoted-app=236-1': 0.0,
#   'ad:promoted-app=236-2': 0.0,
#   'ad:promoted-app=236-3': 0.0,
#   'ad:promoted-app=236-4': 0.0,
#   'ad:promoted-app=236-5': 0.0,
#   'ad:promoted-app=236-6': 0.0,
#   'ad:promoted-app=236-7': 0.0,
#   'ad:promoted-app=236-8': 1.0},
#  'io.voodoo.game_237': {'ad:promoted-app=237-0': 1.0},
#  'io.voodoo.game_238': {'ad:promoted-app=238-0': 1.0},
#  'io.voodoo.game_239': {'ad:promoted-app=239-0': 1.0},
#  'io.voodoo.game_24': {'ad:promoted-app=24-0': 1.0},
#  'io.voodoo.game_240': {'ad:promoted-app=240-0': 0.71625,
#   'ad:promoted-app=240-1': 0.28375},
#  'io.voodoo.game_241': {'ad:promoted-app=241-0': 0.0,
#   'ad:promoted-app=241-1': 0.0,
#   'ad:promoted-app=241-10': 0.9525,
#   'ad:promoted-app=241-2': 0.0,
#   'ad:promoted-app=241-3': 0.0,
#   'ad:promoted-app=241-4': 0.0,
#   'ad:promoted-app=241-5': 0.0,
#   'ad:promoted-app=241-6': 0.0,
#   'ad:promoted-app=241-7': 0.0,
#   'ad:promoted-app=241-8': 0.0475,
#   'ad:promoted-app=241-9': 0.0},
#  'io.voodoo.game_242': {'ad:promoted-app=242-0': 0.0,
#   'ad:promoted-app=242-1': 0.657,
#   'ad:promoted-app=242-2': 0.343},
#  'io.voodoo.game_243': {'ad:promoted-app=243-0': 0.00575,
#   'ad:promoted-app=243-1': 0.298,
#   'ad:promoted-app=243-2': 0.05675,
#   'ad:promoted-app=243-3': 0.32,
#   'ad:promoted-app=243-4': 0.1375,
#   'ad:promoted-app=243-5': 0.182},
#  'io.voodoo.game_244': {'ad:promoted-app=244-0': 0.0555,
#   'ad:promoted-app=244-1': 0.0515,
#   'ad:promoted-app=244-2': 0.01775,
#   'ad:promoted-app=244-3': 0.77475,
#   'ad:promoted-app=244-4': 0.1005},
#  'io.voodoo.game_245': {'ad:promoted-app=245-0': 0.595,
#   'ad:promoted-app=245-1': 0.405},
#  'io.voodoo.game_246': {'ad:promoted-app=246-0': 0.16725,
#   'ad:promoted-app=246-1': 0.83275},
#  'io.voodoo.game_247': {'ad:promoted-app=247-0': 0.48175,
#   'ad:promoted-app=247-1': 0.51825},
#  'io.voodoo.game_248': {'ad:promoted-app=248-0': 1.0},
#  'io.voodoo.game_249': {'ad:promoted-app=249-0': 1.0},
#  'io.voodoo.game_25': {'ad:promoted-app=25-0': 1.0},
#  'io.voodoo.game_250': {'ad:promoted-app=250-0': 1.0},
#  'io.voodoo.game_251': {'ad:promoted-app=251-0': 0.0,
#   'ad:promoted-app=251-1': 0.0,
#   'ad:promoted-app=251-2': 0.0,
#   'ad:promoted-app=251-3': 0.0,
#   'ad:promoted-app=251-4': 0.48475,
#   'ad:promoted-app=251-5': 0.0,
#   'ad:promoted-app=251-6': 0.01525,
#   'ad:promoted-app=251-7': 0.5},
#  'io.voodoo.game_252': {'ad:promoted-app=252-0': 1.0},
#  'io.voodoo.game_253': {'ad:promoted-app=253-0': 0.2335,
#   'ad:promoted-app=253-1': 0.08075,
#   'ad:promoted-app=253-2': 0.00875,
#   'ad:promoted-app=253-3': 0.677},
#  'io.voodoo.game_254': {'ad:promoted-app=254-0': 0.0,
#   'ad:promoted-app=254-1': 0.25,
#   'ad:promoted-app=254-2': 0.0,
#   'ad:promoted-app=254-3': 0.5,
#   'ad:promoted-app=254-4': 0.25,
#   'ad:promoted-app=254-5': 0.0,
#   'ad:promoted-app=254-6': 0.0,
#   'ad:promoted-app=254-7': 0.0},
#  'io.voodoo.game_255': {'ad:promoted-app=255-0': 0.0005,
#   'ad:promoted-app=255-1': 0.126,
#   'ad:promoted-app=255-2': 0.528,
#   'ad:promoted-app=255-3': 0.002,
#   'ad:promoted-app=255-4': 0.089,
#   'ad:promoted-app=255-5': 0.1655,
#   'ad:promoted-app=255-6': 0.0,
#   'ad:promoted-app=255-7': 0.089},
#  'io.voodoo.game_256': {'ad:promoted-app=256-0': 0.00175,
#   'ad:promoted-app=256-1': 0.00125,
#   'ad:promoted-app=256-2': 0.0005,
#   'ad:promoted-app=256-3': 0.00375,
#   'ad:promoted-app=256-4': 0.0005,
#   'ad:promoted-app=256-5': 0.49225,
#   'ad:promoted-app=256-6': 0.0,
#   'ad:promoted-app=256-7': 0.5},
#  'io.voodoo.game_257': {'ad:promoted-app=257-0': 1.0},
#  'io.voodoo.game_258': {'ad:promoted-app=258-0': 1.0},
#  'io.voodoo.game_259': {'ad:promoted-app=259-0': 1.0},
#  'io.voodoo.game_26': {'ad:promoted-app=26-0': 1.0},
#  'io.voodoo.game_27': {'ad:promoted-app=27-0': 0.0,
#   'ad:promoted-app=27-1': 0.0,
#   'ad:promoted-app=27-2': 0.0,
#   'ad:promoted-app=27-3': 0.0,
#   'ad:promoted-app=27-4': 0.0,
#   'ad:promoted-app=27-5': 0.0,
#   'ad:promoted-app=27-6': 0.0,
#   'ad:promoted-app=27-7': 0.0,
#   'ad:promoted-app=27-8': 1.0},
#  'io.voodoo.game_28': {'ad:promoted-app=28-0': 1.0},
#  'io.voodoo.game_29': {'ad:promoted-app=29-0': 1.0},
#  'io.voodoo.game_3': {'ad:promoted-app=3-0': 1.0},
#  'io.voodoo.game_31': {'ad:promoted-app=31-0': 1.0},
#  'io.voodoo.game_32': {'ad:promoted-app=32-0': 1.0},
#  'io.voodoo.game_33': {'ad:promoted-app=33-0': 0.25,
#   'ad:promoted-app=33-1': 0.75,
#   'ad:promoted-app=33-2': 0.0},
#  'io.voodoo.game_34': {'ad:promoted-app=34-0': 0.00075,
#   'ad:promoted-app=34-1': 0.00475,
#   'ad:promoted-app=34-2': 0.0355,
#   'ad:promoted-app=34-3': 0.959},
#  'io.voodoo.game_35': {'ad:promoted-app=35-0': 0.04525,
#   'ad:promoted-app=35-1': 0.0785,
#   'ad:promoted-app=35-2': 0.789,
#   'ad:promoted-app=35-3': 0.04075,
#   'ad:promoted-app=35-4': 0.0465},
#  'io.voodoo.game_36': {'ad:promoted-app=36-0': 0.0,
#   'ad:promoted-app=36-1': 0.0,
#   'ad:promoted-app=36-10': 0.5,
#   'ad:promoted-app=36-11': 0.1635,
#   'ad:promoted-app=36-12': 0.1715,
#   'ad:promoted-app=36-13': 0.0,
#   'ad:promoted-app=36-14': 0.00725,
#   'ad:promoted-app=36-15': 0.0,
#   'ad:promoted-app=36-2': 0.0,
#   'ad:promoted-app=36-3': 0.0,
#   'ad:promoted-app=36-4': 0.15775,
#   'ad:promoted-app=36-5': 0.0,
#   'ad:promoted-app=36-6': 0.0,
#   'ad:promoted-app=36-7': 0.0,
#   'ad:promoted-app=36-8': 0.0,
#   'ad:promoted-app=36-9': 0.0},
#  'io.voodoo.game_38': {'ad:promoted-app=38-0': 0.17925,
#   'ad:promoted-app=38-1': 0.0,
#   'ad:promoted-app=38-10': 0.0,
#   'ad:promoted-app=38-11': 0.32075,
#   'ad:promoted-app=38-12': 0.0,
#   'ad:promoted-app=38-13': 0.0,
#   'ad:promoted-app=38-14': 0.0,
#   'ad:promoted-app=38-15': 0.0,
#   'ad:promoted-app=38-16': 0.5,
#   'ad:promoted-app=38-2': 0.0,
#   'ad:promoted-app=38-3': 0.0,
#   'ad:promoted-app=38-4': 0.0,
#   'ad:promoted-app=38-5': 0.0,
#   'ad:promoted-app=38-6': 0.0,
#   'ad:promoted-app=38-7': 0.0,
#   'ad:promoted-app=38-8': 0.0,
#   'ad:promoted-app=38-9': 0.0},
#  'io.voodoo.game_39': {'ad:promoted-app=39-0': 0.50525,
#   'ad:promoted-app=39-1': 0.49475,
#   'ad:promoted-app=39-2': 0.0,
#   'ad:promoted-app=39-3': 0.0},
#  'io.voodoo.game_4': {'ad:promoted-app=4-0': 1.0},
#  'io.voodoo.game_40': {'ad:promoted-app=89-0': 1.0},
#  'io.voodoo.game_41': {'ad:promoted-app=41-0': 1.0},
#  'io.voodoo.game_42': {'ad:promoted-app=42-0': 0.0,
#   'ad:promoted-app=42-1': 0.0,
#   'ad:promoted-app=42-2': 0.25,
#   'ad:promoted-app=42-3': 0.0,
#   'ad:promoted-app=42-4': 0.04225,
#   'ad:promoted-app=42-5': 0.0,
#   'ad:promoted-app=42-6': 0.20775,
#   'ad:promoted-app=42-7': 0.25,
#   'ad:promoted-app=42-9': 0.25},
#  'io.voodoo.game_43': {'ad:promoted-app=43-0': 0.01875,
#   'ad:promoted-app=43-1': 0.00925,
#   'ad:promoted-app=43-2': 0.00225,
#   'ad:promoted-app=43-3': 0.2695,
#   'ad:promoted-app=43-4': 0.2875,
#   'ad:promoted-app=43-5': 0.0055,
#   'ad:promoted-app=43-6': 0.37525,
#   'ad:promoted-app=43-7': 0.032},
#  'io.voodoo.game_44': {'ad:promoted-app=44-0': 1.0},
#  'io.voodoo.game_45': {'ad:promoted-app=45-0': 1.0},
#  'io.voodoo.game_46': {'ad:promoted-app=46-0': 1.0},
#  'io.voodoo.game_47': {'ad:promoted-app=47-0': 1.0},
#  'io.voodoo.game_48': {'ad:promoted-app=48-0': 1.0},
#  'io.voodoo.game_49': {'ad:promoted-app=49-0': 0.0,
#   'ad:promoted-app=49-1': 0.987,
#   'ad:promoted-app=49-2': 0.013,
#   'ad:promoted-app=49-3': 0.0},
#  'io.voodoo.game_5': {'ad:promoted-app=5-0': 0.052,
#   'ad:promoted-app=5-1': 0.1825,
#   'ad:promoted-app=5-2': 0.01825,
#   'ad:promoted-app=5-3': 0.3035,
#   'ad:promoted-app=5-4': 0.08125,
#   'ad:promoted-app=5-5': 0.03125,
#   'ad:promoted-app=5-6': 0.118,
#   'ad:promoted-app=5-7': 0.21325},
#  'io.voodoo.game_50': {'ad:promoted-app=50-0': 1.0},
#  'io.voodoo.game_51': {'ad:promoted-app=51-0': 1.0},
#  'io.voodoo.game_53': {'ad:promoted-app=53-0': 1.0},
#  'io.voodoo.game_54': {'ad:promoted-app=54-0': 1.0},
#  'io.voodoo.game_55': {'ad:promoted-app=55-0': 1.0},
#  'io.voodoo.game_57': {'ad:promoted-app=57-0': 1.0},
#  'io.voodoo.game_58': {'ad:promoted-app=58-0': 1.0},
#  'io.voodoo.game_59': {'ad:promoted-app=59-0': 0.66525,
#   'ad:promoted-app=59-1': 0.33475},
#  'io.voodoo.game_6': {'ad:promoted-app=6-0': 1.0},
#  'io.voodoo.game_60': {'ad:promoted-app=60-0': 0.00275,
#   'ad:promoted-app=60-1': 0.99725},
#  'io.voodoo.game_61': {'ad:promoted-app=61-0': 1.0},
#  'io.voodoo.game_62': {'ad:promoted-app=62-0': 1.0},
#  'io.voodoo.game_63': {'ad:promoted-app=63-0': 0.01275,
#   'ad:promoted-app=63-1': 0.508,
#   'ad:promoted-app=63-2': 0.47925},
#  'io.voodoo.game_64': {'ad:promoted-app=64-0': 0.46525,
#   'ad:promoted-app=64-1': 0.04425,
#   'ad:promoted-app=64-2': 0.04275,
#   'ad:promoted-app=64-3': 0.4025,
#   'ad:promoted-app=64-4': 0.04525},
#  'io.voodoo.game_65': {'ad:promoted-app=65-0': 0.00025,
#   'ad:promoted-app=65-1': 0.2695,
#   'ad:promoted-app=65-2': 0.068,
#   'ad:promoted-app=65-3': 0.0,
#   'ad:promoted-app=65-4': 0.11625,
#   'ad:promoted-app=65-5': 0.546},
#  'io.voodoo.game_66': {'ad:promoted-app=66-0': 0.5215,
#   'ad:promoted-app=66-1': 0.4785},
#  'io.voodoo.game_67': {'ad:promoted-app=67-0': 1.0},
#  'io.voodoo.game_68': {'ad:promoted-app=68-0': 1.0},
#  'io.voodoo.game_7': {'ad:promoted-app=7-0': 1.0},
#  'io.voodoo.game_70': {'ad:promoted-app=70-0': 1.0},
#  'io.voodoo.game_71': {'ad:promoted-app=71-0': 1.0},
#  'io.voodoo.game_73': {'ad:promoted-app=73-0': 0.0075,
#   'ad:promoted-app=73-1': 0.408,
#   'ad:promoted-app=73-2': 0.00975,
#   'ad:promoted-app=73-3': 0.57475},
#  'io.voodoo.game_74': {'ad:promoted-app=74-0': 1.0},
#  'io.voodoo.game_75': {'ad:promoted-app=75-0': 1.0},
#  'io.voodoo.game_76': {'ad:promoted-app=76-0': 1.0},
#  'io.voodoo.game_78': {'ad:promoted-app=78-0': 1.0},
#  'io.voodoo.game_79': {'ad:promoted-app=79-0': 0.25,
#   'ad:promoted-app=79-1': 0.49425,
#   'ad:promoted-app=79-2': 0.23175,
#   'ad:promoted-app=79-3': 0.024,
#   'ad:promoted-app=79-4': 0.0,
#   'ad:promoted-app=79-5': 0.0},
#  'io.voodoo.game_8': {'ad:promoted-app=8-0': 0.0,
#   'ad:promoted-app=8-1': 0.0,
#   'ad:promoted-app=8-10': 0.0,
#   'ad:promoted-app=8-11': 1.0,
#   'ad:promoted-app=8-2': 0.0,
#   'ad:promoted-app=8-3': 0.0,
#   'ad:promoted-app=8-4': 0.0,
#   'ad:promoted-app=8-5': 0.0,
#   'ad:promoted-app=8-6': 0.0,
#   'ad:promoted-app=8-7': 0.0,
#   'ad:promoted-app=8-8': 0.0,
#   'ad:promoted-app=8-9': 0.0},
#  'io.voodoo.game_80': {'ad:promoted-app=80-0': 0.0,
#   'ad:promoted-app=80-1': 0.23475,
#   'ad:promoted-app=80-10': 0.0,
#   'ad:promoted-app=80-11': 0.25,
#   'ad:promoted-app=80-12': 0.0,
#   'ad:promoted-app=80-2': 0.01525,
#   'ad:promoted-app=80-3': 0.48425,
#   'ad:promoted-app=80-4': 0.0,
#   'ad:promoted-app=80-5': 0.0,
#   'ad:promoted-app=80-6': 0.0,
#   'ad:promoted-app=80-7': 0.0,
#   'ad:promoted-app=80-8': 0.01575,
#   'ad:promoted-app=80-9': 0.0},
#  'io.voodoo.game_81': {'ad:promoted-app=81-0': 1.0},
#  'io.voodoo.game_83': {'ad:promoted-app=83-0': 0.25,
#   'ad:promoted-app=83-1': 0.0,
#   'ad:promoted-app=83-2': 0.46325,
#   'ad:promoted-app=83-3': 0.28675},
#  'io.voodoo.game_84': {'ad:promoted-app=84-0': 0.33625,
#   'ad:promoted-app=84-1': 0.348,
#   'ad:promoted-app=84-2': 0.31575},
#  'io.voodoo.game_85': {'ad:promoted-app=85-0': 1.0},
#  'io.voodoo.game_86': {'ad:promoted-app=86-0': 1.0},
#  'io.voodoo.game_87': {'ad:promoted-app=87-0': 1.0},
#  'io.voodoo.game_89': {'ad:promoted-app=89-0': 1.0},
#  'io.voodoo.game_9': {'ad:promoted-app=9-0': 1.0},
#  'io.voodoo.game_90': {'ad:promoted-app=90-0': 0.25,
#   'ad:promoted-app=90-1': 0.25,
#   'ad:promoted-app=90-2': 0.0,
#   'ad:promoted-app=90-3': 0.25,
#   'ad:promoted-app=90-4': 0.0,
#   'ad:promoted-app=90-5': 0.0,
#   'ad:promoted-app=90-6': 0.25,
#   'ad:promoted-app=90-7': 0.0},
#  'io.voodoo.game_91': {'ad:promoted-app=196-5': 0.0,
#   'ad:promoted-app=91-0': 1.0,
#   'ad:promoted-app=91-1': 0.0,
#   'ad:promoted-app=91-2': 0.0,
#   'ad:promoted-app=91-3': 0.0,
#   'ad:promoted-app=91-4': 0.0,
#   'ad:promoted-app=91-5': 0.0,
#   'ad:promoted-app=91-7': 0.0},
#  'io.voodoo.game_92': {'ad:promoted-app=92-0': 1.0},
#  'io.voodoo.game_93': {'ad:promoted-app=93-0': 0.0,
#   'ad:promoted-app=93-1': 0.0,
#   'ad:promoted-app=93-2': 0.171,
#   'ad:promoted-app=93-3': 0.0,
#   'ad:promoted-app=93-4': 0.329,
#   'ad:promoted-app=93-5': 0.5},
#  'io.voodoo.game_94': {'ad:promoted-app=94-0': 1.0},
#  'io.voodoo.game_95': {'ad:promoted-app=95-0': 1.0},
#  'io.voodoo.game_97': {'ad:promoted-app=97-0': 1.0},
#  'io.voodoo.game_98': {'ad:promoted-app=98-0': 0.0,
#   'ad:promoted-app=98-1': 0.0,
#   'ad:promoted-app=98-2': 0.27775,
#   'ad:promoted-app=98-3': 0.25,
#   'ad:promoted-app=98-4': 0.47225},
#  'io.voodoo.game_99': {'ad:promoted-app=99-0': 0.01625,
#   'ad:promoted-app=99-1': 0.05275,
#   'ad:promoted-app=99-2': 0.29925,
#   'ad:promoted-app=99-3': 0.63175}}
